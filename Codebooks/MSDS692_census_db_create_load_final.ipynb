# %% [markdown]
# # MSDS 692 Practicum 1
# ## Mary Hollon 2-24-2025

# %% [markdown]
# ### Notebook Objective:
#
#  - Created tables in my database censusdb
#  - Load the data
#  - Make data checks using MySQL queries.

# %%
#!pip install tabulate
# This makes the table output more readable

# %%
import mysql.connector
import csv
import pandas as pd

# %%
from getpass import getpass
from mysql.connector import connect, Error
from datetime import datetime

# %% [markdown]
# ### Create a database connection object

# %%
try:
  mydb = connect(
    user='root',    # could be root, or a user you created
    passwd=getpass('Enter password:'),  # the password for that you used
    database='censusdb',   # the database to connect to
    host='127.0.0.1',   # localhost
    # database='boating', # (optional) database to connect to
    allow_local_infile=True  # needed so can load local files
  )
except Error as e:
  print(e)
# Out:
# Enter password: ········

# %% [markdown]
# ## Check if connection is established¶

# %%
print(mydb.is_connected())
# Out:
# True

# %% [markdown]
# ## Create  Database Cursor to Execute DB Commands
#
# cursor = mydb.cursor()
#
# cursor.execute ("show databases")`
#
# for x in cursor:
#     print(x)

# %%
cursor = mydb.cursor()

# %%
# We need to reset the variable that allows loading of local files 
cursor.execute('set global local_infile = 1')

# %% [markdown]
# ## Let's look at all available databases in MySQL:

# %%
cursor.execute ("show databases")  
for x in cursor:
	print(x[0])
# Out:
# censusdb
# companydata
# fitclubdb
# information_schema
# mysql
# performance_schema
# sailor_db_week3
# sakila
# sys
# test
# week2
# world

# %% [markdown]
# ### Specify the database to use:

# %%
cursor.execute('use censusdb')

# %%
# Create Tables for Census database censusdb

# Create Demographics Table

cursor.execute("""CREATE TABLE IF NOT EXISTS Demographics (
    state VARCHAR(50),
    year INT,
    total_population INT,
    median_age FLOAT,
    male_population INT,
    female_population INT,
    white_population INT,
    black_population INT,
    asian_population INT,
    hispanic_population INT,
    veteran_status INT,
    foreign_born_population INT,
    non_english_speakers INT,
    PRIMARY KEY (state, year)
)""");

# %%
# print out which tables are in censusdb
cursor.execute ("show tables") 
for x in cursor:
	print(x)
# Out:
# ('demographics',)
# ('education',)
# ('health_insurance',)
# ('housing',)
# ('income',)
# ('transportation',)

# %%
from tabulate import tabulate

cursor.execute("DESCRIBE demographics;")
columns = cursor.fetchall()

# Convert the list of tuples into a list of lists for tabulate
table = [list(col) for col in columns]

# Define column headers
headers = ["Field", "Type", "Null", "Key", "Default", "Extra"]

# Print as a formatted table
print(tabulate(table, headers=headers, tablefmt="grid"))
# Out:
# +-------------------------+-------------+--------+-------+-----------+---------+
# | Field                   | Type        | Null   | Key   | Default   | Extra   |
# +=========================+=============+========+=======+===========+=========+
# | state                   | varchar(50) | NO     | PRI   |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | year                    | int         | NO     | PRI   |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | total_population        | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | median_age              | float       | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | male_population         | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | female_population       | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | white_population        | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | black_population        | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | asian_population        | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | hispanic_population     | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | veteran_status          | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | foreign_born_population | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+
# | non_english_speakers    | int         | YES    |       |           |         |
# +-------------------------+-------------+--------+-------+-----------+---------+

# %% [markdown]
# ### Let's Create the Remaining Tables:

# %%
# Create Income Table

cursor.execute("""CREATE TABLE IF NOT EXISTS Income (
    state VARCHAR(50),
    year INT,
    median_household_income INT,
    per_capita_income INT,
    population_in_poverty INT,
    total_population_for_poverty INT,
    unemployed_population INT,
    labor_force_population INT,
    PRIMARY KEY (state, year),
    FOREIGN KEY (state, year) REFERENCES Demographics(state, year)
)""");

# Create Housing Table
cursor.execute("""CREATE TABLE IF NOT EXISTS Housing (
    state VARCHAR(50),
    year INT,
    total_households INT,
    owner_occupied_homes INT,
    renter_occupied_homes INT,
    median_home_value INT,
    median_rent INT,
    cost_burdened_households INT,
    vacancy_rate FLOAT,
    average_household_size FLOAT,
    PRIMARY KEY (state, year),
    FOREIGN KEY (state, year) REFERENCES Demographics(state, year)
)""");

# Create Transportation Table
cursor.execute("""CREATE TABLE IF NOT EXISTS Transportation (
    state VARCHAR(50),
    year INT,
    mean_travel_time FLOAT,
    car_commute INT,
    public_transit_commute INT,
    walk_commute INT,
    work_from_home INT,
    PRIMARY KEY (state, year),
    FOREIGN KEY (state, year) REFERENCES Demographics(state, year)
)""");

# Create Health Insurance Table
cursor.execute("""CREATE TABLE IF NOT EXISTS Health_Insurance (
    state VARCHAR(50),
    year INT,
    total_insured_population INT,
    total_uninsured_population INT,
    private_insurance INT,
    public_insurance INT,
    no_health_insurance INT,
    PRIMARY KEY (state, year),
    FOREIGN KEY (state, year) REFERENCES Demographics(state, year)
)""");

# Create Education Table
cursor.execute("""CREATE TABLE IF NOT EXISTS Education (
    state VARCHAR(50),
    year INT,
    total_population_25_over INT,
    less_than_hs INT,
    high_school_graduate INT,
    some_college INT,
    associates_degree INT,
    bachelors_degree INT,
    graduate_degree INT,
    PRIMARY KEY (state, year),
    FOREIGN KEY (state, year) REFERENCES Demographics(state, year)
)""");

# %% [markdown]
# ##  Verify Table Creation

# %%
#Let's look at the tables to make sure they exist in the database

# print out which tables are in censusdb

cursor.execute ("show tables") 
for x in cursor:
	print(x)
# Out:
# ('demographics',)
# ('education',)
# ('health_insurance',)
# ('housing',)
# ('income',)
# ('transportation',)

# %% [markdown]
# #### The desired tables are all here. Next, let's verify their structures

# %%
# List of table names
tables = ["education", "health_insurance", "housing", "income", "transportation"]

for table_name in tables:
    cursor.execute(f"DESCRIBE {table_name};")
    columns = cursor.fetchall()

    # Convert the list of tuples into a list of lists for tabulate
    table = [list(col) for col in columns]

    # Define column headers
    headers = ["Field", "Type", "Null", "Key", "Default", "Extra"]

    # Print table name as a header
    print(f"\nSchema for table: {table_name}")
    print(tabulate(table, headers=headers, tablefmt="grid"))
# Out:
# Schema for table: education
# +--------------------------+-------------+--------+-------+-----------+---------+
# | Field                    | Type        | Null   | Key   | Default   | Extra   |
# +==========================+=============+========+=======+===========+=========+
# | state                    | varchar(50) | NO     | PRI   |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | year                     | int         | NO     | PRI   |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | total_population_25_over | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | less_than_hs             | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | high_school_graduate     | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | some_college             | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | associates_degree        | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | bachelors_degree         | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | graduate_degree          | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
#
# Schema for table: health_insurance
# +----------------------------+-------------+--------+-------+-----------+---------+
# | Field                      | Type        | Null   | Key   | Default   | Extra   |
# +============================+=============+========+=======+===========+=========+
# | state                      | varchar(50) | NO     | PRI   |           |         |
# +----------------------------+-------------+--------+-------+-----------+---------+
# | year                       | int         | NO     | PRI   |           |         |
# +----------------------------+-------------+--------+-------+-----------+---------+
# | total_insured_population   | int         | YES    |       |           |         |
# +----------------------------+-------------+--------+-------+-----------+---------+
# | total_uninsured_population | int         | YES    |       |           |         |
# +----------------------------+-------------+--------+-------+-----------+---------+
# | private_insurance          | int         | YES    |       |           |         |
# +----------------------------+-------------+--------+-------+-----------+---------+
# | public_insurance           | int         | YES    |       |           |         |
# +----------------------------+-------------+--------+-------+-----------+---------+
# | no_health_insurance        | int         | YES    |       |           |         |
# +----------------------------+-------------+--------+-------+-----------+---------+
#
# Schema for table: housing
# +--------------------------+-------------+--------+-------+-----------+---------+
# | Field                    | Type        | Null   | Key   | Default   | Extra   |
# +==========================+=============+========+=======+===========+=========+
# | state                    | varchar(50) | NO     | PRI   |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | year                     | int         | NO     | PRI   |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | total_households         | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | owner_occupied_homes     | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | renter_occupied_homes    | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | median_home_value        | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | median_rent              | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | cost_burdened_households | int         | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | vacancy_rate             | float       | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
# | average_household_size   | float       | YES    |       |           |         |
# +--------------------------+-------------+--------+-------+-----------+---------+
#
# Schema for table: income
# +------------------------------+-------------+--------+-------+-----------+---------+
# | Field                        | Type        | Null   | Key   | Default   | Extra   |
# +==============================+=============+========+=======+===========+=========+
# | state                        | varchar(50) | NO     | PRI   |           |         |
# +------------------------------+-------------+--------+-------+-----------+---------+
# | year                         | int         | NO     | PRI   |           |         |
# +------------------------------+-------------+--------+-------+-----------+---------+
# | median_household_income      | int         | YES    |       |           |         |
# +------------------------------+-------------+--------+-------+-----------+---------+
# | per_capita_income            | int         | YES    |       |           |         |
# +------------------------------+-------------+--------+-------+-----------+---------+
# | population_in_poverty        | int         | YES    |       |           |         |
# +------------------------------+-------------+--------+-------+-----------+---------+
# | total_population_for_poverty | int         | YES    |       |           |         |
# +------------------------------+-------------+--------+-------+-----------+---------+
# | unemployed_population        | int         | YES    |       |           |         |
# +------------------------------+-------------+--------+-------+-----------+---------+
# | labor_force_population       | int         | YES    |       |           |         |
# +------------------------------+-------------+--------+-------+-----------+---------+
#
# Schema for table: transportation
# +------------------------+-------------+--------+-------+-----------+---------+
# | Field                  | Type        | Null   | Key   | Default   | Extra   |
# +========================+=============+========+=======+===========+=========+
# | state                  | varchar(50) | NO     | PRI   |           |         |
# +------------------------+-------------+--------+-------+-----------+---------+
# | year                   | int         | NO     | PRI   |           |         |
# +------------------------+-------------+--------+-------+-----------+---------+
# | mean_travel_time       | float       | YES    |       |           |         |
# +------------------------+-------------+--------+-------+-----------+---------+
# | car_commute            | int         | YES    |       |           |         |
# +------------------------+-------------+--------+-------+-----------+---------+
# | public_transit_commute | int         | YES    |       |           |         |
# +------------------------+-------------+--------+-------+-----------+---------+
# | walk_commute           | int         | YES    |       |           |         |
# +------------------------+-------------+--------+-------+-----------+---------+
# | work_from_home         | int         | YES    |       |           |         |
# +------------------------+-------------+--------+-------+-----------+---------+

# %% [markdown]
# ### The table structures are verified. Next Load the data.

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\Users\mjhol\OneDrive\MSDE 631 SQL_NoSQL\Week4_MySQL_Python_Connector

# %%
#"C:\Users\mjhol\OneDrive\MSDS 692 Practicum 1\acs_data_2013.csv"

os.chdir("C:/Users/mjhol/OneDrive/MSDS 692 Practicum 1")

# %% [markdown]
# Because All of the Table Data was pulled as one big file, I have to break up the data according to each table's parameters. The years and The table Columns are defined before loading the data.

# %%
import pandas as pd

# Database Connection
cursor = mydb.cursor()

# List of years
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# Define table column mappings
table_columns = {
    "Demographics": ["State", "Year", "Total_Population", "Median_Age", "Male_Population", 
                     "Female_Population", "White_Population", "Black_Population", 
                     "Asian_Population", "Hispanic_Population", "Veteran_Status", 
                     "Foreign_Born_Population", "Non_English_Speakers"],

    "Income": ["State", "Year", "Median_Household_Income", "Per_Capita_Income", 
               "Population_in_Poverty", "Total_Population_for_Poverty", 
               "Unemployed_Population", "Labor_Force_Population"],

    "Housing": ["State", "Year", "Total_Households", "Owner_Occupied_Homes", 
                "Renter_Occupied_Homes", "Median_Home_Value", "Median_Rent", 
                "Cost_Burdened_Households", "Vacancy_Rate", "Average_Household_Size"],

    "Transportation": ["State", "Year", "Mean_Travel_Time", "Car_Commute", 
                       "Public_Transit_Commute", "Walk_Commute", "Work_From_Home"],

    "Health_Insurance": ["State", "Year", "Total_Insured_Population", 
                         "Total_Uninsured_Population", "Private_Insurance", 
                         "Public_Insurance", "No_Health_Insurance"],

    "Education": ["State", "Year", "Total_Population_25_Over", "Less_Than_HS", 
                  "High_School_Graduate", "Some_College", "Associates_Degree", 
                  "Bachelors_Degree", "Graduate_Degree"]
}

# Function to insert data
def insert_data(table_name, dataframe):
    placeholders = ", ".join(["%s"] * len(dataframe.columns))
    columns = ", ".join(dataframe.columns)
    query = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"

    for row in dataframe.itertuples(index=False, name=None):
        cursor.execute(query, row)

    mydb.commit()
    print(f"✅ Data inserted into {table_name} for {dataframe['Year'].iloc[0]}")

# Loop through each year and process data
for year in years:
    file_path = f"acs_data_{year}.csv"

    # Check if file exists
    if not os.path.exists(file_path):
        print(f"❌ File not found: {file_path}")
        continue
    
    print(f"📂 Processing file: {file_path}")

    # Load CSV
    df = pd.read_csv(file_path)

    # Ensure proper formatting
    df["State"] = df["State"].str.strip()
    df["Year"] = df["Year"].astype(int)

    # Insert data into each table
    for table, cols in table_columns.items():
        table_df = df[cols]
        insert_data(table, table_df)

# Close the connection
cursor.close()
mydb.close()

print("🎉 All data successfully loaded into MySQL!")
# Out:
# 📂 Processing file: acs_data_2013.csv
# ✅ Data inserted into Demographics for 2013
# ✅ Data inserted into Income for 2013
# ✅ Data inserted into Housing for 2013
# ✅ Data inserted into Transportation for 2013
# ✅ Data inserted into Health_Insurance for 2013
# ✅ Data inserted into Education for 2013
# 📂 Processing file: acs_data_2014.csv
# ✅ Data inserted into Demographics for 2014
# ✅ Data inserted into Income for 2014
# ✅ Data inserted into Housing for 2014
# ✅ Data inserted into Transportation for 2014
# ✅ Data inserted into Health_Insurance for 2014
# ✅ Data inserted into Education for 2014
# 📂 Processing file: acs_data_2015.csv
# ✅ Data inserted into Demographics for 2015
# ✅ Data inserted into Income for 2015
# ✅ Data inserted into Housing for 2015
# ✅ Data inserted into Transportation for 2015
# ✅ Data inserted into Health_Insurance for 2015
# ✅ Data inserted into Education for 2015
# 📂 Processing file: acs_data_2016.csv
# ✅ Data inserted into Demographics for 2016
# ✅ Data inserted into Income for 2016
# ✅ Data inserted into Housing for 2016
# ✅ Data inserted into Transportation for 2016
# ✅ Data inserted into Health_Insurance for 2016
# ✅ Data inserted into Education for 2016
# 📂 Processing file: acs_data_2017.csv
# ✅ Data inserted into Demographics for 2017
# ✅ Data inserted into Income for 2017
# ✅ Data inserted into Housing for 2017
# ✅ Data inserted into Transportation for 2017
# ✅ Data inserted into Health_Insurance for 2017
# ✅ Data inserted into Education for 2017
# 📂 Processing file: acs_data_2018.csv
# ✅ Data inserted into Demographics for 2018
# ✅ Data inserted into Income for 2018
# ✅ Data inserted into Housing for 2018
# ✅ Data inserted into Transportation for 2018
# ✅ Data inserted into Health_Insurance for 2018
# ✅ Data inserted into Education for 2018
# 📂 Processing file: acs_data_2019.csv
# ✅ Data inserted into Demographics for 2019
# ✅ Data inserted into Income for 2019
# ✅ Data inserted into Housing for 2019
# ✅ Data inserted into Transportation for 2019
# ✅ Data inserted into Health_Insurance for 2019
# ✅ Data inserted into Education for 2019
# 📂 Processing file: acs_data_2020.csv
# ✅ Data inserted into Demographics for 2020
# ✅ Data inserted into Income for 2020
# ✅ Data inserted into Housing for 2020
# ✅ Data inserted into Transportation for 2020
# ✅ Data inserted into Health_Insurance for 2020
# ✅ Data inserted into Education for 2020
# 📂 Processing file: acs_data_2021.csv
# ✅ Data inserted into Demographics for 2021
# ✅ Data inserted into Income for 2021
# ✅ Data inserted into Housing for 2021
# ✅ Data inserted into Transportation for 2021
# ✅ Data inserted into Health_Insurance for 2021
# ✅ Data inserted into Education for 2021
# 📂 Processing file: acs_data_2022.csv
# ✅ Data inserted into Demographics for 2022
# ✅ Data inserted into Income for 2022
# ✅ Data inserted into Housing for 2022
# ✅ Data inserted into Transportation for 2022
# ✅ Data inserted into Health_Insurance for 2022
# ✅ Data inserted into Education for 2022
# 🎉 All data successfully loaded into MySQL!

# %%
#!pip install --upgrade numpy pandas

# %%
# Try to connect to the database properly
try:
    mydb = mysql.connector.connect(
        user='root',    
        passwd=getpass('Enter password:'),  
        database='censusdb',   
        host='127.0.0.1',   
        allow_local_infile=True  
    )
    print("✅ Connected to MySQL database")

except Error as e:
    print(f"❌ Error connecting to database: {e}")
    exit()  # Stop execution if connection fails
# Out:
# Enter password: ········
# ✅ Connected to MySQL database

# %% [markdown]
# ## Explore The Data To Ensure it Has Loaded Properly

# %%
# Create a new cursor
cursor = mydb.cursor()

# Ensure any unread results are handled before running a new query
try:
    while cursor.nextset():
        cursor.fetchall()  # Clear any unread results
except:
    pass  # Ignore errors if no unread results exist

# Execute the query safely
try:
    query = """
        SELECT 'Demographics' AS TableName, COUNT(*) AS RowCount FROM Demographics
        UNION ALL
        SELECT 'Income', COUNT(*) FROM Income
        UNION ALL
        SELECT 'Housing', COUNT(*) FROM Housing
        UNION ALL
        SELECT 'Transportation', COUNT(*) FROM Transportation
        UNION ALL
        SELECT 'Health_Insurance', COUNT(*) FROM Health_Insurance
        UNION ALL
        SELECT 'Education', COUNT(*) FROM Education
    """
    
    cursor.execute(query)
    results = cursor.fetchall()

    # Display the results
    print("\n📊 Table Row Counts:")
    for row in results:
        print(row)

except Error as e:
    print(f"❌ Error executing query: {e}")
# Out:
# 📊 Table Row Counts:
# ('Demographics', 520)
# ('Income', 520)
# ('Housing', 520)
# ('Transportation', 520)
# ('Health_Insurance', 520)
# ('Education', 520)

# %% [markdown]
# ### The Table Row Counts are as Expected.
# Next, I will explore the tables to ensure that the data is loaded correctly and as expected.
# To Make the output easier to read, I will display the query results in a Pandas Dataframe

# %%
query = """SELECT * FROM Demographics LIMIT 20"""
cursor.execute(query)

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

results = cursor.fetchall()

# Convert results into a Pandas DataFrame
df = pd.DataFrame(results, columns=column_names)

# Display the results
df.head(20)
# Out:
#       state  year  total_population  median_age  male_population  \
# 0   Alabama  2013           4799277        38.1          2328592
# 1   Alabama  2014           4817678        38.2          2336020
# 2   Alabama  2015           4830620        38.4          2341093
# 3   Alabama  2016           4841164        38.6          2346193
# 4   Alabama  2017           4850771        38.7          2350806
# 5   Alabama  2018           4864680        38.9          2355799
# 6   Alabama  2019           4876250        39.0          2359355
# 7   Alabama  2020           4893186        39.2          2365734
# 8   Alabama  2021           4997675        39.3          2429703
# 9   Alabama  2022           5028092        39.3          2445995
# 10   Alaska  2013            720316        33.6           375798
# 11   Alaska  2014            728300        33.4           380119
# 12   Alaska  2015            733375        33.4           384160
# 13   Alaska  2016            736855        33.6           385296
# 14   Alaska  2017            738565        33.9           386319
# 15   Alaska  2018            738516        34.0           385579
# 16   Alaska  2019            737068        34.3           384915
# 17   Alaska  2020            736990        34.6           384653
# 18   Alaska  2021            735951        35.0           384749
# 19   Alaska  2022            734821        35.3           386649
#
#     female_population  white_population  black_population  asian_population  \
# 0             2470685           3326188           1262152             56831
# 1             2481658           3327891           1269808             58322
# 2             2489527           3325464           1276544             59599
# 3             2494971           3325037           1282053             60744
# 4             2499965           3317702           1287167             62815
# 5             2508881           3317453           1293186             64609
# 6             2516895           3320247           1299048             66270
# 7             2527452           3302834           1301319             67909
# 8             2567972           3338590           1324233             70161
# 9             2582097           3329012           1326341             69808
# 10             344518            481638             25033             39200
# 11             348181            484195             25148             40976
# 12             349215            484250             25022             42921
# 13             351559            483518             24443             44218
# 14             352246            481971             23702             45604
# 15             352937            478834             24129             46556
# 16             352153            476015             24205             45920
# 17             352337            466961             23894             47289
# 18             351202            458520             23721             47213
# 19             348172            450472             23395             47464
#
#     hispanic_population  veteran_status  foreign_born_population  \
# 0                188294         3660703                   168232
# 1                191838         3685939                   166477
# 2                193492         3705690                   167224
# 3                193503         3723825                   165504
# 4                198375         3735780                   167926
# 5                203146         3753332                   168111
# 6                208626         3766571                   172947
# 7                212951         3785626                   168053
# 8                224659         3859695                   173429
# 9                232407         3902062                   177207
# 10                42832          515714                    50375
# 11                45247          523434                    51680
# 12                47808          528564                    54047
# 13                49031          532857                    55247
# 14                50162          535290                    56043
# 15                51186          535244                    57399
# 16                51870          534918                    57667
# 17                53059          534765                    57342
# 18                53604          533140                    57925
# 19                54890          534602                    58074
#
#     non_english_speakers
# 0                4497352
# 1                4518107
# 2                4535566
# 3                4548393
# 4                4558608
# 5                4572555
# 6                4583063
# 7                4599254
# 8                4702043
# 9                4736236
# 10                665954
# 11                673802
# 12                678422
# 13                682423
# 14                684298
# 15                684276
# 16                683831
# 17                684688
# 18                685160
# 19                685830

# %%
query = """SELECT * FROM Education LIMIT 20"""
cursor.execute(query)

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

results = cursor.fetchall()

# Convert results into a Pandas DataFrame
df = pd.DataFrame(results, columns=column_names)

# Display the results
df.head(20)
# Out:
#       state  year  total_population_25_over  less_than_hs  \
# 0   Alabama  2013                   3193338         40711
# 1   Alabama  2014                   3217902         41671
# 2   Alabama  2015                   3239351         41876
# 3   Alabama  2016                   3261408         42577
# 4   Alabama  2017                   3276637         41118
# 5   Alabama  2018                   3299958         41240
# 6   Alabama  2019                   3320877         40837
# 7   Alabama  2020                   3344006         41430
# 8   Alabama  2021                   3413803         43813
# 9   Alabama  2022                   3428520         45445
# 10   Alaska  2013                    454301          2796
# 11   Alaska  2014                    460319          2924
# 12   Alaska  2015                    464440          2977
# 13   Alaska  2016                    470699          3020
# 14   Alaska  2017                    475442          3451
# 15   Alaska  2018                    477727          3479
# 16   Alaska  2019                    480586          3434
# 17   Alaska  2020                    483436          3172
# 18   Alaska  2021                    484382          3675
# 19   Alaska  2022                    485871          3875
#
#     high_school_graduate  some_college  associates_degree  bachelors_degree  \
# 0                 818315        511830             458393            187852
# 1                 824979        514936             465268            196935
# 2                 826272        516724             478812            201997
# 3                 828205        517123             492382            208839
# 4                 831994        513751             503930            216001
# 5                 838776        514121             515443            221842
# 6                 841716        508105             529178            230528
# 7                 839252        512048             546674            239746
# 8                 864345        514689             563628            251040
# 9                 864977        507480             572252            261039
# 10                101267         96565              80447             31988
# 11                103345         96871              82261             32681
# 12                105527         96130              83201             33447
# 13                106169         94936              86551             35423
# 14                106162         94589              88308             35770
# 15                107913         93703              88053             36794
# 16                108797         91792              88058             37958
# 17                110980         88422              90161             39156
# 18                111772         86787              92691             39503
# 19                114087         85203              93744             39645
#
#     graduate_degree
# 0             30801
# 1             31815
# 2             32332
# 3             32572
# 4             34195
# 5             34881
# 6             35796
# 7             38455
# 8             41681
# 9             42980
# 10             5068
# 11             5126
# 12             5002
# 13             5029
# 14             4865
# 15             5292
# 16             5630
# 17             6058
# 18             6028
# 19             6419

# %%
query = """SELECT * FROM Income LIMIT 20"""
cursor.execute(query)

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

results = cursor.fetchall()

# Convert results into a Pandas DataFrame
df1 = pd.DataFrame(results, columns=column_names)

# Display the results
df1.tail(10)
# Out:
#      state  year  median_household_income  per_capita_income  \
# 10  Alaska  2013                    70760              32651
# 11  Alaska  2014                    71829              33129
# 12  Alaska  2015                    72515              33413
# 13  Alaska  2016                    74444              34191
# 14  Alaska  2017                    76114              35065
# 15  Alaska  2018                    76715              35874
# 16  Alaska  2019                    77640              36787
# 17  Alaska  2020                    77790              37094
# 18  Alaska  2021                    80287              39236
# 19  Alaska  2022                    86370              42828
#
#     population_in_poverty  total_population_for_poverty  \
# 10                  69514                        704041
# 11                  71866                        711235
# 12                  72957                        716218
# 13                  72826                        719064
# 14                  73380                        719983
# 15                  77865                        720674
# 16                  76933                        719376
# 17                  74369                        719445
# 18                  75016                        719086
# 19                  75227                        717293
#
#     unemployed_population  labor_force_population
# 10                  32939                  393037
# 11                  32097                  396856
# 12                  31285                  399077
# 13                  30139                  400475
# 14                  29548                  400622
# 15                  28067                  396353
# 16                  26808                  392338
# 17                  26429                  386787
# 18                  25054                  383795
# 19                  23035                  383078

# %%
import pandas as pd

query = "SELECT * FROM Transportation LIMIT 20"
cursor.execute(query)

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

# Fetch results
results = cursor.fetchall()

# Convert results into a Pandas DataFrame
df = pd.DataFrame(results, columns=column_names)

# Display the DataFrame
df.head(20)
# Out:
#       state  year  mean_travel_time  car_commute  public_transit_commute  \
# 0   Alabama  2013        46428500.0      1869731                    8935
# 1   Alabama  2014        46805400.0      1877915                    8943
# 2   Alabama  2015        47251900.0      1888257                    8452
# 3   Alabama  2016        47968200.0      1903947                    7841
# 4   Alabama  2017        48314300.0      1916975                    7433
# 5   Alabama  2018        49084900.0      1934423                    6959
# 6   Alabama  2019        49913600.0      1953288                    6927
# 7   Alabama  2020        50359400.0      1953038                    6960
# 8   Alabama  2021        51105500.0      1975704                    7097
# 9   Alabama  2022        51658900.0      1985736                    6982
# 10   Alaska  2013         6223520.0       279760                    5634
# 11   Alaska  2014         6372220.0       284016                    5617
# 12   Alaska  2015         6483780.0       287377                    5849
# 13   Alaska  2016         6478690.0       290233                    5425
# 14   Alaska  2017         6490010.0       291855                    5453
# 15   Alaska  2018         6426000.0       290566                    4981
# 16   Alaska  2019         6468980.0       288451                    4640
# 17   Alaska  2020         6250960.0       281851                    4247
# 18   Alaska  2021         6323580.0       277640                    4139
# 19   Alaska  2022         6227600.0       274263                    3805
#
#     walk_commute  work_from_home
# 0          23233           51785
# 1          22697           53344
# 2          22288           55668
# 3          23010           58991
# 4          22659           62502
# 5          22977           66881
# 6          23376           69165
# 7          23265           92836
# 8          23088          120723
# 9          24058          145406
# 10         27584           17261
# 11         27830           16698
# 12         27734           16304
# 13         28304           16575
# 14         28714           15850
# 15         27575           16731
# 16         27220           17026
# 17         26789           21184
# 18         25805           24822
# 19         27039           28281

# %%
query = """SELECT * FROM Housing LIMIT 20"""
cursor.execute(query)

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

results = cursor.fetchall()

# Convert results into a Pandas DataFrame
df = pd.DataFrame(results, columns=column_names)

# Display the results
df.head(10)
# Out:
#      state  year  total_households  owner_occupied_homes  \
# 0  Alabama  2013           2178116               1281604
# 1  Alabama  2014           2190638               1274196
# 2  Alabama  2015           2199329               1269145
# 3  Alabama  2016           2209335               1267824
# 4  Alabama  2017           2231126               1273217
# 5  Alabama  2018           2244462               1275223
# 6  Alabama  2019           2255026               1284748
# 7  Alabama  2020           2270398               1306505
# 8  Alabama  2021           2278526               1320571
# 9  Alabama  2022           2296920               1347792
#
#    renter_occupied_homes  median_home_value  median_rent  \
# 0                 557079             122500          705
# 1                 567978             123800          715
# 2                 579180             125500          717
# 3                 583237             128500          728
# 4                 583478             132100          747
# 5                 585046             137200          772
# 6                 583145             142700          792
# 7                 581999             149600          811
# 8                 582412             157100          852
# 9                 585358             179400          925
#
#    cost_burdened_households  vacancy_rate  average_household_size
# 0                     43229      339433.0                    2.55
# 1                     43125      348464.0                    2.55
# 2                     44060      351004.0                    2.55
# 3                     43058      358274.0                    2.55
# 4                     43678      374431.0                    2.55
# 5                     43244      384193.0                    2.55
# 6                     42905      387133.0                    2.55
# 7                     42640      381894.0                    2.53
# 8                     44097      375543.0                    2.57
# 9                     45062      363770.0                    2.53

# %%
query = """SELECT * FROM Health_Insurance LIMIT 20"""
cursor.execute(query)

# Fetch column names
column_names = [desc[0] for desc in cursor.description]

results = cursor.fetchall()

# Convert results into a Pandas DataFrame
df = pd.DataFrame(results, columns=column_names)

# Display the results
df.head(10)
# Out:
#      state  year  total_insured_population  total_uninsured_population  \
# 0  Alabama  2013                   4716915                       57347
# 1  Alabama  2014                   4735953                       51606
# 2  Alabama  2015                   4749786                       45500
# 3  Alabama  2016                   4761291                       39111
# 4  Alabama  2017                   4770692                       41459
# 5  Alabama  2018                   4785040                       38671
# 6  Alabama  2019                   4797215                       36972
# 7  Alabama  2020                   4813429                       36714
# 8  Alabama  2021                   4920010                       40628
# 9  Alabama  2022                   4944981                       39485
#
#    private_insurance  public_insurance  no_health_insurance
# 0            1121332            294979               300398
# 1            1115913            286339               299742
# 2            1110011            265669               287141
# 3            1103328            245685               264957
# 4            1170330            221678               245506
# 5            1165772            204561               231101
# 6            1162995            193275               224687
# 7            1160135            190423               224992
# 8            1190423            193735               239179
# 9            1184371            193271               235651

# %% [markdown]
# ## Next, Check For Duplicate Rows by State and Year

# %%
query = """SELECT State, Year, COUNT(*) AS RowCount
FROM Demographics
GROUP BY State, Year
HAVING COUNT(*) > 1"""

cursor.execute(query)
results = cursor.fetchall()

# Print results
print("\n Duplicate Records in Demographics:")
for row in results:
    print(row)
# Out:
#  Duplicate Records in Demographics:

# %%
query = """SELECT State, Year, COUNT(*) AS RowCount
FROM Income
GROUP BY State, Year
HAVING COUNT(*) > 1"""

cursor.execute(query)
results = cursor.fetchall()

# Print results
print("\n Duplicate Records in Income:")
for row in results:
    print(row)
# Out:
#  Duplicate Records in Income:

# %%
query = """SELECT State, Year, COUNT(*) AS RowCount
FROM Housing
GROUP BY State, Year
HAVING COUNT(*) > 1"""

cursor.execute(query)
results = cursor.fetchall()

# Print results
print("\n Duplicate Records in Housing:")
for row in results:
    print(row)
# Out:
#  Duplicate Records in Housing:

# %%
query = """SELECT State, Year, COUNT(*) AS RowCount
FROM Transportation
GROUP BY State, Year
HAVING COUNT(*) > 1"""

cursor.execute(query)
results = cursor.fetchall()

# Print results
print("\n Duplicate Records in Transportation:")
for row in results:
    print(row)
# Out:
#  Duplicate Records in Transportation:

# %%
query = """SELECT State, Year, COUNT(*) AS RowCount
FROM Health_Insurance
GROUP BY State, Year
HAVING COUNT(*) > 1"""

cursor.execute(query)
results = cursor.fetchall()

# Print results
print("\n Duplicate Records in Health_Insurance:")
for row in results:
    print(row)
# Out:
#  Duplicate Records in Health_Insurance:

# %%
query = """SELECT State, Year, COUNT(*) AS RowCount
FROM Education
GROUP BY State, Year
HAVING COUNT(*) > 1"""

cursor.execute(query)
results = cursor.fetchall()

# Print results
print("\n Duplicate Records in Education:")
for row in results:
    print(row)
# Out:
#  Duplicate Records in Education:

# %% [markdown]
# ### None of the tables contain duplicate rows

# %% [markdown]
# ### Spot Check For NULL Values in the Data

# %%
query = """
    SELECT State, Year, Total_Population, Median_Age 
    FROM Demographics 
    WHERE Total_Population IS NULL OR Median_Age IS NULL 
    ORDER BY Year, State
    LIMIT 10
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)

# %%
query = """
    SELECT State, Year, Median_Household_Income, Population_in_Poverty
    FROM Income
    WHERE Median_Household_Income IS NULL OR Population_in_Poverty IS NULL 
    ORDER BY Year, State
    LIMIT 10
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)

# %%
query = """
    SELECT State, Year, Total_Households, Median_Home_Value
    FROM Housing
    WHERE Total_Households IS NULL OR  Median_Home_Value IS NULL 
    ORDER BY Year, State
    LIMIT 10
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)

# %%
query = """
    SELECT State, Year, Mean_Travel_Time, Car_Commute
    FROM Transportation
    WHERE Mean_Travel_Time IS NULL OR  Car_Commute IS NULL 
    ORDER BY Year, State
    LIMIT 10
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)

# %%
query = """
    SELECT State, Year, Total_Insured_Population, No_Health_Insurance
    FROM Health_Insurance
    WHERE Total_Insured_Population IS NULL OR  No_Health_Insurance IS NULL 
    ORDER BY Year, State
    LIMIT 10
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)

# %%
query = """
    SELECT State, Year, Total_Population_25_Over , Bachelors_Degree
    FROM Education
    WHERE Total_Population_25_Over  IS NULL OR  Bachelors_Degree IS NULL 
    ORDER BY Year, State
    LIMIT 10
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)

# %% [markdown]
# ### The Spot Checks Look Good
#
# ### Perform One More Check For Distinct States for 2 of the tables

# %%
query = """
SELECT DISTINCT State FROM Demographics
ORDER BY State
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Alabama',)
# ('Alaska',)
# ('Arizona',)
# ('Arkansas',)
# ('California',)
# ('Colorado',)
# ('Connecticut',)
# ('Delaware',)
# ('District of Columbia',)
# ('Florida',)
# ('Georgia',)
# ('Hawaii',)
# ('Idaho',)
# ('Illinois',)
# ('Indiana',)
# ('Iowa',)
# ('Kansas',)
# ('Kentucky',)
# ('Louisiana',)
# ('Maine',)
# ('Maryland',)
# ('Massachusetts',)
# ('Michigan',)
# ('Minnesota',)
# ('Mississippi',)
# ('Missouri',)
# ('Montana',)
# ('Nebraska',)
# ('Nevada',)
# ('New Hampshire',)
# ('New Jersey',)
# ('New Mexico',)
# ('New York',)
# ('North Carolina',)
# ('North Dakota',)
# ('Ohio',)
# ('Oklahoma',)
# ('Oregon',)
# ('Pennsylvania',)
# ('Puerto Rico',)
# ('Rhode Island',)
# ('South Carolina',)
# ('South Dakota',)
# ('Tennessee',)
# ('Texas',)
# ('Utah',)
# ('Vermont',)
# ('Virginia',)
# ('Washington',)
# ('West Virginia',)
# ('Wisconsin',)
# ('Wyoming',)

# %%
query = """
SELECT DISTINCT State FROM Education
ORDER BY State
"""
cursor.execute(query)
results = cursor.fetchall()

for row in results:
    print(row)
# Out:
# ('Alabama',)
# ('Alaska',)
# ('Arizona',)
# ('Arkansas',)
# ('California',)
# ('Colorado',)
# ('Connecticut',)
# ('Delaware',)
# ('District of Columbia',)
# ('Florida',)
# ('Georgia',)
# ('Hawaii',)
# ('Idaho',)
# ('Illinois',)
# ('Indiana',)
# ('Iowa',)
# ('Kansas',)
# ('Kentucky',)
# ('Louisiana',)
# ('Maine',)
# ('Maryland',)
# ('Massachusetts',)
# ('Michigan',)
# ('Minnesota',)
# ('Mississippi',)
# ('Missouri',)
# ('Montana',)
# ('Nebraska',)
# ('Nevada',)
# ('New Hampshire',)
# ('New Jersey',)
# ('New Mexico',)
# ('New York',)
# ('North Carolina',)
# ('North Dakota',)
# ('Ohio',)
# ('Oklahoma',)
# ('Oregon',)
# ('Pennsylvania',)
# ('Puerto Rico',)
# ('Rhode Island',)
# ('South Carolina',)
# ('South Dakota',)
# ('Tennessee',)
# ('Texas',)
# ('Utah',)
# ('Vermont',)
# ('Virginia',)
# ('Washington',)
# ('West Virginia',)
# ('Wisconsin',)
# ('Wyoming',)

# %% [markdown]
# ### The Output is as Expected. These queries returned a list of distinct state names

# %% [markdown]
# ### Close the database

# %%
# Close the cursor and database connection safely
# Close the connection
cursor.close()
mydb.close()
print("✅ Database connection closed.")
# Out:
# ✅ Database connection closed.

# %% [markdown]
# ## END OF NOTEBOOK
#
# This Notebook created tables in my database censusdb, loaded the data, and made data checks using MySQL queries as stated in the notebook objective.
